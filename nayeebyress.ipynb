# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('s_data.csv')
df
# Out:
#    color   legs height smelly species
# 0  white  three  short    yes       m
# 1  green    two   tall     no       m
# 2  green  three  short    yes       m
# 3  white  three  short    yes       m
# 4  green    two  short     no       h
# 5  white    two   tall     no       h
# 6  white    two   tall     no       h
# 7  white    two  short    yes       h

# %%
def run_navie_bayes_classification():
    print("--dataset--")
    print(df)
    print("--processing--")
    X = df.drop("species", axis=1)
    y = df["species"]

    encoder = OrdinalEncoder()
    X_encoded = encoder.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split( X_encoded, y, test_size=0.25, random_state=42)

    model = CategoricalNB()
    model.fit(X_train, y_train)


    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy * 100:.2f}%")

    new_data=pd.DataFrame([['white','three','short','yes']],
                         columns=['color','legs','height','smelly'])

    new_encoded = encoder.transform(new_data)
    prediction=model.predict(new_encoded)
    proba = model.predict_proba(new_encoded)
    print("\n------final reslut-----------")
    print(f"new applicant:white,3 leg,short,smelly")
    print("Predicted species:", prediction[0])
    print("prediction probablity: ",proba)

# %%
run_navie_bayes_classification()
# Out:
# --dataset--
#    color   legs height smelly species
# 0  white  three  short    yes       m
# 1  green    two   tall     no       m
# 2  green  three  short    yes       m
# 3  white  three  short    yes       m
# 4  green    two  short     no       h
# 5  white    two   tall     no       h
# 6  white    two   tall     no       h
# 7  white    two  short    yes       h
# --processing--
# Accuracy: 50.00%
#
# ------final reslut-----------
# new applicant:white,3 leg,short,smelly
# Predicted species: m
# prediction probablity:  [[0.08571429 0.91428571]]
